# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Baseball.csv")

# %%
df.head(10)
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5  93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86
# 5  34   88
# 6  48   93
# ...

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# No null values in the data

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Data Visualisation

# %%
plt.scatter(df['R'],df['W'],color='g',alpha=0.6)

# %% [raw]
# From the above plot we can see there is a positive relation between Runs "R" and Wins "W"

# %%
plt.scatter(df['AB'],df['W'],color='g',alpha=0.6)

# %% [raw]
# Not getting clear information from above plot

# %%
plt.scatter(df['2B'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows positive relation between Doubles and Wins

# %%
plt.scatter(df['3B'],df['W'],color='g',alpha=0.6)

# %%
plt.scatter(df['HR'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows some positive relation

# %%
plt.scatter(df['BB'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows some positive relation

# %%
plt.scatter(df['SO'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows some positive relation

# %%
plt.scatter(df['SB'],df['W'],color='g',alpha=0.6)

# %%
plt.scatter(df['RA'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows negetive relation

# %%
plt.scatter(df['ER'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows negetive relation

# %%
plt.scatter(df['ERA'],df['W'],color='g',alpha=0.6)

# %% [raw]
# The above plot shows negetive relation

# %%
plt.scatter(df['CG'],df['W'],color='g',alpha=0.6)

# %%
plt.scatter(df['SHO'],df['W'],color='g',alpha=0.6)

# %% [raw]
# Shows some positive relation

# %%
plt.scatter(df['SV'],df['W'],color='g',alpha=0.6)

# %% [raw]
# Shows some positive relation

# %%
plt.scatter(df['E'],df['W'],color='g',alpha=0.6)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.distplot(df["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df["R"])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df["AB"])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df["H"])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df["2B"])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df["3B"])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df["HR"])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df["BB"])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df["SB"])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df["SO"])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df["RA"])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df["ERA"])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df["CG"])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df["SHO"])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df["SV"])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df["E"])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [raw]
# The above plots shows that the data is not normalised.

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
loss_percent=(30-29)/30*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [raw]
# Dividing data in features and vectors

# %%
x=df_new.drop("W",axis=1)
y=df_new['W']

# %% [markdown]
# # Linear Regresssion

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state{i},the training accuracy is:-{r2_score(y_train,pred_train)}")
    print(f"At random state{i},the testing accuracy is:-{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is:-0.979301718690075
# At random state0,the testing accuracy is:-0.37642412024128413
#
#
# At random state1,the training accuracy is:-0.9693516004448695
# At random state1,the testing accuracy is:-0.7555241414909563
#
#
# At random state2,the training accuracy is:-0.9664881232216764
# At random state2,the testing accuracy is:--0.3292909249905507
#
#
# At random state3,the training accuracy is:-0.9534657143080713
# At random state3,the testing accuracy is:-0.8485894004113762
#
#
# At random state4,the training accuracy is:-0.9611298547801516
# At random state4,the testing accuracy is:-0.7514775069642694
#
#
# At random state5,the training accuracy is:-0.961798902227327
# At random state5,the testing accuracy is:-0.5545096693427249
#
#
# At random state6,the training accuracy is:-0.9603217707835179
# At random state6,the testing accuracy is:-0.7473255183245064
#
#
# At random state7,the training accuracy is:-0.9590946505307434
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=30)

# %%
y_pred=lr.predict(x_train)
print("Training Accuracy:",lr.score(x_train,y_train)*100)
# Out:
# Training Accuracy: 91.48834790703435

# %%
print("Testing Accuracy:",lr.score(x_test,y_test)*100)
# Out:
# Testing Accuracy: 95.02145992525399

# %%
print("Model Accuracy:",r2_score(y,lr.predict(x))*100)
# Out:
# Model Accuracy: 92.6285591789682

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor()
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=reg.predict(x_train)

# %%
print("Training Accuracy:",reg.score(x_train,y_train)*100)
# Out:
# Training Accuracy: 92.95507904061051

# %%
print("Testing Accuracy:",reg.score(x_test,y_test)*100)
# Out:
# Testing Accuracy: 55.78162833356855

# %%
print("Model Accuracy:",r2_score(y,reg.predict(x))*100)
# Out:
# Model Accuracy: 82.1334714925305

# %% [markdown]
# # Prediction and Final Score:

# %% [raw]
# Linear Regression
#
# Model Score: 86.29% Accuracy, Training Accuracy: 95.40% Accuracy, Testing Accuracy: 64.14% Accuracy
#
# Random Forest Regressor
#
# Model Score: 82.10% Accuracy, Training Accuracy: 93.28% Accuracy, Testing Accuracy: 54.89% Accuracy

# %%
import pickle
filename="Baseball_predicion.csv"
pickle.dump(lr,open(filename,"wb"))
